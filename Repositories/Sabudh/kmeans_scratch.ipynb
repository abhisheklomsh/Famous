# %%
import pandas as pd
import numpy as np
from sklearn.datasets import make_blobs
from matplotlib import pyplot as plt
# %matplotlib inline
from scipy.spatial.distance import cdist

# %%
X,y= make_blobs(n_samples=1000,n_features=2,centers=3,cluster_std=1.8)
centers,label=make_blobs(n_samples=3,n_features=2,centers=3,cluster_std=1.8)
count=0

# %%
X.shape
# Out:
# (1000, 2)

# %%
centers
# Out:
# array([[-4.40498568,  8.24698013],
#        [ 0.77945372,  6.18369903],
#        [-4.51028738,  7.84165282]])

# %%
euclidean_dist = cdist(X,centers,metric='euclidean')
min_dist = np.argmin(euclidean_dist,axis=1)

n_values = np.max(min_dist) + 1
hot_encoding = pd.get_dummies(y)
hot_encoding1=np.array(hot_encoding)
print(hot_encoding1.shape)
print(X.shape)
print(np.sum(hot_encoding1,axis=0).shape)

data = np.dot(hot_encoding1.T,X)/np.sum(hot_encoding1,axis=0).reshape(3,1)
# Out:
# (1000, 3)
# (1000, 2)
# (3,)

# %%
def kmeans(X,y,centers,label,count):
    
    #X=pd.DataFrame(X)
    #centers=pd.DataFrame(centers)
    #plt.scatter(X[0],X[1],cmap='rainbow',c=y)
    euclidean_dist = cdist(X,centers,metric='euclidean')
    min_dist = np.argmin(euclidean_dist,axis=1)
   
    n_values = np.max(min_dist) + 1
    hot_encoding = pd.get_dummies(y)
    hot_encoding1=np.array(hot_encoding)
    print(hot_encoding1.shape)
    print(X.shape)
    print(np.sum(hot_encoding1,axis=0).shape)
    
    data = np.dot(hot_encoding1.T,X)/(np.sum(hot_encoding1,axis=0).reshape(3,1))  
    print(data)
    

    #print(newk1)
    centers=data
    #centers = np.concatenate((newk2,newk3,newk4,newk5),axis=0).reshape(100,5)
    data2=pd.DataFrame(data)
    #plt.scatter(data[0],data[1],cmap='twilight',c=label)
    
    plt.scatter(X[0],X[1],cmap='rainbow')
    plt.scatter(pd.DataFrame(data2[0]),data2[1],marker='*', c='#050505', s=1000)
    plt.show()
    count+=1
    print(count)
    return centers,count

# %%
for i in range(100):
    centers,count=kmeans(X,y,centers,label,count)
count=0
# Out:
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 1
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 2
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 3
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 4
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 5
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 6
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 7
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 8
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 9
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 10
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 11
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 12
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 13
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 14
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 15
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 16
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 17
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 18
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 19
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 20
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 21
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 22
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 23
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 24
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 25
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 26
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 27
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 28
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 29
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 30
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 31
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 32
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 33
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 34
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 35
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 36
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 37
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 38
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 39
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 40
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 41
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 42
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 43
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 44
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 45
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 46
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 47
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 48
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 49
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 50
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 51
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 52
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 53
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 54
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 55
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 56
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 57
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 58
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 59
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 60
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 61
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 62
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 63
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 64
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 65
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 66
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 67
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 68
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 69
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 70
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 71
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 72
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 73
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 74
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 75
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 76
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 77
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 78
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 79
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 80
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 81
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 82
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 83
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 84
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 85
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 86
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 87
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 88
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 89
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 90
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 91
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 92
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 93
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 94
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 95
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 96
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 97
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 98
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 99
# (1000, 3)
# (1000, 2)
# (3,)
# [[-4.03877396  5.53365072]
#  [ 4.35904526 -1.40094135]
#  [ 2.82837512 -6.04112301]]
# 100
