# %%
import pandas as pd
import numpy as np
from sklearn.datasets import make_blobs
from matplotlib import pyplot as plt
# %matplotlib inline
from scipy.spatial.distance import cdist

# %%
X,y= make_blobs(n_samples=1000,n_features=2,centers=3,cluster_std=1.8)
centers,label=make_blobs(n_samples=3,n_features=2,centers=3,cluster_std=1.8)
count=0

# %%
X.shape
# Out:
# (1000, 2)

# %%
centers
# Out:
# array([[-0.4205352 ,  3.30837405],
#        [-4.73868849, -9.29482783],
#        [-5.50714706,  2.63219854]])

# %%
euclidean_dist = cdist(X,centers,metric='euclidean')
min_dist = np.argmin(euclidean_dist,axis=1)

n_values = np.max(min_dist) + 1
hot_encoding = pd.get_dummies(y)
hot_encoding1=np.array(hot_encoding)
print(hot_encoding1.shape)
print(X.shape)
print(np.sum(hot_encoding1,axis=0).shape)

data = np.dot(hot_encoding1.T,X)/np.sum(hot_encoding1,axis=0).reshape(3,1)  
print(data)
# Out:
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]

# %%
def kmeans(X,y,centers,label,count):
    
    #X=pd.DataFrame(X)
    #centers=pd.DataFrame(centers)
    #plt.scatter(X[0],X[1],cmap='rainbow',c=y)
    euclidean_dist = cdist(X,centers,metric='euclidean')
    min_dist = np.argmin(euclidean_dist,axis=1)
   
    n_values = np.max(min_dist) + 1
    hot_encoding = pd.get_dummies(y)
    hot_encoding1=np.array(hot_encoding)
    print(hot_encoding1.shape)
    print(X.shape)
    print(np.sum(hot_encoding1,axis=0).shape)
    
    data = np.dot(hot_encoding1.T,X)/np.sum(hot_encoding1,axis=0).reshape(3,1)
    print(data)
    

    #print(newk1)
    centers=data
    #centers = np.concatenate((newk2,newk3,newk4,newk5),axis=0).reshape(100,5)
    data2=pd.DataFrame(data)
    #plt.scatter(data[0],data[1],cmap='twilight',c=label)
    
    #plt.scatter(X[0],X[1],cmap='rainbow',c=y)
    plt.scatter(pd.DataFrame(data2[0]),data2[1],marker='*', c='#050505', s=1000)
    plt.show()
    count+=1
    print(count)
    return centers,count
#X=pd.DataFrame(X)
    #centers=pd.DataFrame(centers)
    #plt.scatter(X[0],X[1],cmap='rainbow',c=y)
    euclidean_dist = cdist(X,centers,metric='euclidean')
    min_dist = np.argmin(euclidean_dist,axis=1)
   
    n_values = np.max(min_dist) + 1
    hot_encoding = pd.get_dummies(y)
    hot_encoding1=np.array(hot_encoding)
    print(hot_encoding1.shape)
    print(X.shape)
    print(np.sum(hot_encoding1,axis=0).shape)
    
    data = np.dot(hot_encoding1.T,X)/np.sum(hot_encoding1,axis=0).reshape(3,1)
    print(data)
    

    #print(newk1)
    centers=data
    #centers = np.concatenate((newk2,newk3,newk4,newk5),axis=0).reshape(100,5)
    data2=pd.DataFrame(data)
    #plt.scatter(data[0],data[1],cmap='twilight',c=label)
    
    #plt.scatter(X[0],X[1],cmap='rainbow',c=y)
    plt.scatter(pd.DataFrame(data2[0]),data2[1],marker='*', c='#050505', s=1000)
    plt.show()
    count+=1
    print(count)
    return centers,count
#X=pd.DataFrame(X)
    #centers=pd.DataFrame(centers)
    #plt.scatter(X[0],X[1],cmap='rainbow',c=y)
    euclidean_dist = cdist(X,centers,metric='euclidean')
    min_dist = np.argmin(euclidean_dist,axis=1)
   
    n_values = np.max(min_dist) + 1
    hot_encoding = pd.get_dummies(y)
    hot_encoding1=np.array(hot_encoding)
    print(hot_encoding1.shape)
    print(X.shape)
    print(np.sum(hot_encoding1,axis=0).shape)
    
    data = np.dot(hot_encoding1.T,X)/np.sum(hot_encoding1,axis=0).reshape(3,1)
    print(data)
    

    #print(newk1)
    centers=data
    #centers = np.concatenate((newk2,newk3,newk4,newk5),axis=0).reshape(100,5)
    data2=pd.DataFrame(data)
    #plt.scatter(data[0],data[1],cmap='twilight',c=label)
    
    #plt.scatter(X[0],X[1],cmap='rainbow',c=y)
    plt.scatter(pd.DataFrame(data2[0]),data2[1],marker='*', c='#050505', s=1000)
    plt.show()
    count+=1
    print(count)
    return centers,count
#X=pd.DataFrame(X)
    #centers=pd.DataFrame(centers)
    #plt.scatter(X[0],X[1],cmap='rainbow',c=y)
    euclidean_dist = cdist(X,centers,metric='euclidean')
    min_dist = np.argmin(euclidean_dist,axis=1)
   
    n_values = np.max(min_dist) + 1
    hot_encoding = pd.get_dummies(y)
    hot_encoding1=np.array(hot_encoding)
    print(hot_encoding1.shape)
    print(X.shape)
    print(np.sum(hot_encoding1,axis=0).shape)
    
    data = np.dot(hot_encoding1.T,X)/np.sum(hot_encoding1,axis=0).reshape(3,1)
    print(data)
    

    #print(newk1)
    centers=data
    #centers = np.concatenate((newk2,newk3,newk4,newk5),axis=0).reshape(100,5)
    data2=pd.DataFrame(data)
    #plt.scatter(data[0],data[1],cmap='twilight',c=label)
    
    #plt.scatter(X[0],X[1],cmap='rainbow',c=y)
    plt.scatter(pd.DataFrame(data2[0]),data2[1],marker='*', c='#050505', s=1000)
    plt.show()
    count+=1
    print(count)
    return centers,count
#X=pd.DataFrame(X)
    #centers=pd.DataFrame(centers)
    #plt.scatter(X[0],X[1],cmap='rainbow',c=y)
    euclidean_dist = cdist(X,centers,metric='euclidean')
    min_dist = np.argmin(euclidean_dist,axis=1)
   
    n_values = np.max(min_dist) + 1
    hot_encoding = pd.get_dummies(y)
    hot_encoding1=np.array(hot_encoding)
    print(hot_encoding1.shape)
    print(X.shape)
    print(np.sum(hot_encoding1,axis=0).shape)
    
    data = np.dot(hot_encoding1.T,X)/np.sum(hot_encoding1,axis=0).reshape(3,1)
    print(data)
    

    #print(newk1)
    centers=data
    #centers = np.concatenate((newk2,newk3,newk4,newk5),axis=0).reshape(100,5)
    data2=pd.DataFrame(data)
    #plt.scatter(data[0],data[1],cmap='twilight',c=label)
    
    #plt.scatter(X[0],X[1],cmap='rainbow',c=y)
    plt.scatter(pd.DataFrame(data2[0]),data2[1],marker='*', c='#050505', s=1000)
    plt.show()
    count+=1
    print(count)
    return centers,count

# %%
for i in range(5):
    centers,count=kmeans(X,y,centers,label,count)
count=0
# Out:
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 1
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 2
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 3
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 4
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 5
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 6
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 7
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 8
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 9
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 10
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 11
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 12
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 13
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 14
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 15
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 16
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 17
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 18
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 19
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 20
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 21
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 22
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 23
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 24
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 25
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 26
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 27
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 28
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 29
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 30
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 31
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 32
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 33
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 34
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 35
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 36
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 37
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 38
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 39
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 40
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 41
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 42
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 43
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 44
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 45
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 46
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 47
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 48
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 49
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 50
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 51
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 52
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 53
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 54
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 55
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 56
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 57
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 58
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 59
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 60
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 61
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 62
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 63
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 64
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 65
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 66
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 67
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 68
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 69
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 70
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 71
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 72
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 73
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 74
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 75
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 76
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 77
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 78
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 79
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 80
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 81
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 82
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 83
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 84
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 85
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 86
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 87
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 88
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 89
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 90
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 91
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 92
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 93
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 94
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 95
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 96
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 97
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 98
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 99
# (1000, 3)
# (1000, 2)
# (3,)
# [[ 2.32224448  6.59624985]
#  [-5.91673271  6.24950379]
#  [ 7.19934333 -9.0339455 ]]
# 100
